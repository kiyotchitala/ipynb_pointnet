# %% [markdown]
# normalize.txtの点群を見るノートブックです

# %%
import glob
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

files = glob.glob('./normalize_txt/40_95/test_tree/*')
if len(files) == 0:
    print("No data available")
else:
    randnum = random.randint(0,len(files))
    with open(files[randnum],'r') as f:
        datas = f.read().split('\n')

fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(111, projection='3d')
for idx in range(len(datas)-1):
    data = datas[idx]
    if not data == '':
        d_s = data.split(' ')
        if float(d_s[2]) == 95:
            ax.scatter(float(d_s[0]),float(d_s[1]),float(d_s[2]),s=40,c='red')
        else:
            ax.scatter(float(d_s[0]),float(d_s[1]),float(d_s[2]),s=40,c='blue')
plt.show()

# %%
import glob
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

files = glob.glob('./normalize_txt/tree/*')
if len(files) == 0:
    print("No data available")
else:
    randnum = random.randint(0,len(files))
    with open(files[randnum],'r') as f:
        datas = f.read().split('\n')

fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(111, projection='3d')
for idx,data in enumerate(datas):
    if not data == '':
        d_s = data.split(' ')
        ax.scatter(float(d_s[0]),float(d_s[1]),float(d_s[2]),s=40,c='blue')
plt.show()

# %%
import glob
over_files = glob.glob('./normalize_txt/test_64_over_tree/*')
#file = glob.glob('./normalize_txt/tree/')
for idx,file in enumerate(files):
    with open(file,'r') as f:
        data = f.read()
        d_s = data.split('\n')
    with open('./normalize_txt/tree/{}.txt'.format(idx),'a') as ff:
        for i in range(32):
            ff.write(d_s[i]+'\n')
